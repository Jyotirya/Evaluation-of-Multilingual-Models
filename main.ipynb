# %%
import pandas as pd

# %%
df_arabic_test = pd.read_json('../tweet_sentiment_multilingual/data/arabic/test.jsonl', lines=True)
df_arabic_train = pd.read_json('../tweet_sentiment_multilingual/data/arabic/train.jsonl', lines=True)
df_arabic_val = pd.read_json('../tweet_sentiment_multilingual/data/arabic/validation.jsonl', lines=True)
df_english_test = pd.read_json('../tweet_sentiment_multilingual/data/english/test.jsonl', lines=True)
df_english_train = pd.read_json('../tweet_sentiment_multilingual/data/english/train.jsonl', lines=True)
df_english_val = pd.read_json('../tweet_sentiment_multilingual/data/english/validation.jsonl', lines=True)
df_french_test = pd.read_json('../tweet_sentiment_multilingual/data/french/test.jsonl', lines=True)
df_french_train = pd.read_json('../tweet_sentiment_multilingual/data/french/train.jsonl', lines=True)
df_french_val = pd.read_json('../tweet_sentiment_multilingual/data/french/validation.jsonl', lines=True)       
df_german_test = pd.read_json('../tweet_sentiment_multilingual/data/german/test.jsonl', lines=True)
df_german_train = pd.read_json('../tweet_sentiment_multilingual/data/german/train.jsonl', lines=True)
df_german_val = pd.read_json('../tweet_sentiment_multilingual/data/german/validation.jsonl', lines=True)       
df_italian_test = pd.read_json('../tweet_sentiment_multilingual/data/italian/test.jsonl', lines=True)
df_italian_train = pd.read_json('../tweet_sentiment_multilingual/data/italian/train.jsonl', lines=True)
df_italian_val = pd.read_json('../tweet_sentiment_multilingual/data/italian/validation.jsonl', lines=True)       
df_spanish_test = pd.read_json('../tweet_sentiment_multilingual/data/spanish/test.jsonl', lines=True)
df_spanish_train = pd.read_json('../tweet_sentiment_multilingual/data/spanish/train.jsonl', lines=True)
df_spanish_val = pd.read_json('../tweet_sentiment_multilingual/data/spanish/validation.jsonl', lines=True)
df_hindi_test = pd.read_json('../tweet_sentiment_multilingual/data/hindi/test.jsonl', lines=True)
df_hindi_train = pd.read_json('../tweet_sentiment_multilingual/data/hindi/train.jsonl', lines=True)
df_hindi_val = pd.read_json('../tweet_sentiment_multilingual/data/hindi/validation.jsonl', lines=True)
df_portuguese_test = pd.read_json('../tweet_sentiment_multilingual/data/portuguese/test.jsonl', lines=True)
df_portuguese_train = pd.read_json('../tweet_sentiment_multilingual/data/portuguese/train.jsonl', lines=True)
df_portuguese_val = pd.read_json('../tweet_sentiment_multilingual/data/portuguese/validation.jsonl', lines=True)
